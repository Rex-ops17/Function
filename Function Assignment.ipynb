# %%
# Thery Answer

""" (1)  A function in Python is a block of reusable code that performs a specific task. It can be defined independently of any object or class. Functions are defined using the def keyword, and they can be called by simply using their name and passing arguments (if required).
         A method, however, is a function that is bound to an object and defined inside a class. Methods work on the data of the object to which they are bound and are invoked by using an instance of the class. The first argument passed in calling a method is the object to which it is bound (commonly known as self). Functions are not class members, and methods are class members that modify the attributes of an object."""


""" (2)  Parameters are the variables declared in the function definition. They indicate what type of values the function expects to receive when invoked. In other words, parameters are placeholders used in the function signature to receive values.
         Arguments are the values that are sent to the function when it is called. They constitute the data of which the function performs its tasks. Parameters and arguments are normally used synonymously, but to be more formal, parameters pertain to variables within the definition of a function, whereas the argument refers to the values submitted to the function."""

"""(3) Different ways of Definition and Call to a Function of Python:
          1-Simple functions are defined with the def keyword and perform specific tasks.
          2-Functions with default arguments allow you to set default values for parameters, making the function more flexible.
          3-Functions with variable arguments (*args, **kwargs) allow the function to accept a flexible number of positional and keyword arguments.
          4-Lambda functions are anonymous, small functions used for simple tasks.
          5-Recursive functions call themselves to solve problems by breaking them down into smaller instances."""


""" (4) The return statement in a function is used to exit the function and send back a result or value to the caller. It terminates the function's execution and provides the output. Without a return statement, the function returns None by default.
        The purpose of return is to allow functions to output data, making it possible to use the result in further computations or operations."""


""" (5) Iterable: Any object in Python that could return an iterator is called an iterable. Anything that can be used in a for loop is an iterable.
        An iterator is an object that presents a stream of data. The difference between an iterator and an iterable is that an iterator has memory for its current position, and it can be iterated using the next() function. It generates an iterator from an iterable to work through its items one by one."""


""" (6) A generator is a special type of iterator that lets you iterate over data one item at a time but does not store all values in memory at once, as with lists or tuples."""


""" (7) Memory Efficiency: Generators only produce one item at a time and do not store the entire sequence in memory.
        Lazy Evaluation: Generators enable lazy evaluation. This means that values are generated only when they are needed. This may improve performance and avoid unnecessary computations.
        State Preservation: Because generators preserve their state between yield calls, they can resume their execution from where they left off, which makes them useful for creating iterative processes without recalculating previous steps.


""(8) A lambda function in Python is an anonymous function defined using the keyword lambda. It can take any number of input parameters but has only one expression."""


""" (9) Map() function of Python applies a given function to all items in an iterable and returns an iterator that yields results. It is particularly helpful in transforming or processing each element in an iterable without explicitly writing a loop."""


""" (10) map(): The map() function applies a given function to all items in an iterable and returns an iterator with the results. It is used when you want to apply a transformation to each item in an iterable.
         reduce(): The reduce() function from the functools module applies a binary function  cumulatively to the items in an iterable, from left to right, to reduce the iterable to a single value. It is often used for operations like summing, multiplying, or concatenating values.
         filter(): The filter() function filters elements from an iterable based on a function that returns True or False for each element. It returns an iterator containing only those elements for which the function returned True."""


""" (11) Step 1: First Pair (47 and 11)
        The lambda function is called with x = 47 and y = 11:
        𝑥+𝑦=47+11=58
        x+y=47+11=58
        Result after this step: 58

        Step 2: Next Pair (Result from Step 1 and 42)
        The lambda function is called with x = 58 (result of the previous step) and y = 42:
        𝑥+𝑦=58+42=100
        x+y=58+42=100
        Result after this step: 100

        Step 3: Next Pair (Result from Step 2 and 13)
        The lambda function is called with x = 100 (result of the previous step) and y = 13:
         𝑥+𝑦=100+13=113
         x+y=100+13=113
         Final result: 113

         3. Final Output
          The sum of all the elements in the list [47, 11, 42, 13] using the reduce function is:
            Sum=113"""

# %%
# PRACTICAL QUESTION

# Answer 1
def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)
# Example usage:
numbers = [1, 2, 3, 4, 5, 6]
print(sum_even_numbers(numbers))  # Output: 12 (2 + 4 + 6)


# Answer 2
def reverse_string(s):
    return s[::-1]
# Example usage:
print(reverse_string("hello"))  # Output: "olleh"


# Answer 3
def square_numbers(numbers):
    return [num ** 2 for num in numbers]
# Example usage:
print(square_numbers([1, 2, 3, 4]))  # Output: [1, 4, 9, 16]


# Answer 4
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True
# Example usage:
for num in range(1, 201):
    if is_prime(num):
        print(num, end=" ")  # Output: List of prime numbers between 1 and 200


#Answer 5
class FibonacciIterator:
    def __init__(self, terms):
        self.terms = terms
        self.a, self.b = 0, 1
        self.count = 0
    def __iter__(self):
        return self
    def __next__(self):
        if self.count < self.terms:
            value = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return value
        else:
            raise StopIteration
# Example usage:
fib = FibonacciIterator(10)
for num in fib:
    print(num, end=" ")  # Output: Fibonacci sequence up to 10 terms


#Answer 6
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i
# Example usage:
for power in powers_of_two(5):
    print(power, end=" ")  # Output: 1 2 4 8 16 32


#Answer 7
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()  # .strip() to remove newline characters
# Example usage:
# Make sure to create a test file "example.txt" before running this
# for line in read_file_line_by_line("example.txt"):
#     print(line)


#Answer 8
my_list = [(1, 2), (3, 1), (5, 4)]
sorted_list = sorted(my_list, key=lambda x: x[1])
# Example usage:
print(sorted_list)  # Output: [(3, 1), (1, 2), (5, 4)]


#Answer 9
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32
# Example usage:
celsius_temps = [0, 10, 20, 30]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))

print(fahrenheit_temps)  # Output: [32.0, 50.0, 68.0, 86.0]


#Answer 10
def remove_vowels(s):
    vowels = "aeiouAEIOU"
    return ''.join(filter(lambda x: x not in vowels, s))
# Example usage:
input_string = "Hello World"
print(remove_vowels(input_string))  # Output: "Hll Wrld"


#Answer 11
# Input list of orders
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99],
    ]


# Using map and lambda
result = list(map(
    lambda order: (order[0], round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)),
    orders
))

# Output the result
print(result)

# Result
[(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
